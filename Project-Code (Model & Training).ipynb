# %%
# !pip3 install torch torchvision torchaudio

# %%
cd yolov5
# Out:
# /Users/aliyajanmohamed/Downloads/Ironhack/FinalProject/yolov5

# %%
# !pip install -r requirements.txt

# %%
import torch
import numpy as np
import cv2
import matplotlib.pyplot as plt
import pandas as pd

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in /Users/aliyajanmohamed/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-6-1 Python-3.11.3 torch-2.0.1 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
img = "https://m.media-amazon.com/images/M/MV5BMzMwYWZkZjctZTU5Ny00MDNiLTlkMmYtNzkyODMwMGUxYzA2XkEyXkFqcGdeQXVyNzU1NzE3NTg@._V1_.jpg"

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 360x480 2 cars
# Speed: 149.4ms pre-process, 468.4ms inference, 2.3ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cd yolov5
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /Users/aliyajanmohamed/Downloads/Ironhack/FinalProject/yolov5

# %%
# !python train.py --img 640 --batch 5 --epochs 300 --data custom.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=5, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-175-g5f11555 Python-3.11.3 torch-2.0.1 CPU
#
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 5 --data custom.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-175-g5f11555 Python-3.11.3 torch-2.0.1 CPU
#
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 20 --data custom.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-175-g5f11555 Python-3.11.3 torch-2.0.1 CPU
#
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 5 --data custom.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-175-g5f11555 Python-3.11.3 torch-2.0.1 CPU
#
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 5 --data custom.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-175-g5f11555 Python-3.11.3 torch-2.0.1 CPU
#
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 10 --data custom.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-175-g5f11555 Python-3.11.3 torch-2.0.1 CPU
#
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 20 --data custom.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-175-g5f11555 Python-3.11.3 torch-2.0.1 CPU
#
# ...

# %%
# !python detect.py --weights runs/train/exp16/weights/best.pt --source /Users/aliyajanmohamed/Downloads/Ironhack/FinalProject/data/images/test
# Out:
# detect: weights=['runs/train/exp16/weights/best.pt'], source=/Users/aliyajanmohamed/Downloads/Ironhack/FinalProject/data/images/test, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-175-g5f11555 Python-3.11.3 torch-2.0.1 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/18 /Users/aliyajanmohamed/Downloads/Ironhack/FinalProject/data/images/test/63650690_1004.jpeg: 288x640 1 elephants, 438.8ms
# image 2/18 /Users/aliyajanmohamed/Downloads/Ironhack/FinalProject/data/images/test/79d75eec-919c-11ed-beb9-0210609a.jpeg: 448x640 (no detections), 430.5ms
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data custom.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-175-g5f11555 Python-3.11.3 torch-2.0.1 CPU
#
# ...

# %%
# !python detect.py --weights runs/train/exp18/weights/best.pt --source /Users/aliyajanmohamed/Downloads/Ironhack/FinalProject/data/images/test
# Out:
# detect: weights=['runs/train/exp18/weights/best.pt'], source=/Users/aliyajanmohamed/Downloads/Ironhack/FinalProject/data/images/test, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-175-g5f11555 Python-3.11.3 torch-2.0.1 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/18 /Users/aliyajanmohamed/Downloads/Ironhack/FinalProject/data/images/test/63650690_1004.jpeg: 288x640 1 elephants, 225.8ms
# image 2/18 /Users/aliyajanmohamed/Downloads/Ironhack/FinalProject/data/images/test/79d75eec-919c-11ed-beb9-0210609a.jpeg: 448x640 1 poachers, 336.8ms
# ...

# %%
model = torch.hub.load('/Users/aliyajanmohamed/Downloads/Ironhack/FinalProject/yolov5', 'custom', 
                       path='/Users/aliyajanmohamed/Downloads/Ironhack/FinalProject/yolov5/runs/train/exp18/weights/best.pt',
                       force_reload=True,source='local')
# Out:
# YOLOv5 🚀 v7.0-175-g5f11555 Python-3.11.3 torch-2.0.1 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
img="https://cdn.24.co.za/files/Cms/General/d/11611/dca2f657ec514001a425ffa364fc11f6.jpg"

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 683x1024 1 elephants
# Speed: 1866.9ms pre-process, 443.5ms inference, 37.2ms NMS per image at shape (1, 3, 448, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
img = "https://pulitzercenter.org/sites/default/files/styles/1340x815_scale/public/09-07-17/dscf7233.jpg.webp?itok=arxwLQr0"

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 815x1087 3 poacherss
# Speed: 343.1ms pre-process, 353.4ms inference, 1.3ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()
